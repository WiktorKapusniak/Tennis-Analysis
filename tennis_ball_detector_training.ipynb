# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.63-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (3.10.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (2.2.5)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.1.63-py3-none-any.whl (85 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 7.3 MB/s eta 0:00:0000:0100:01
# Downloading pillow_heif-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idnam╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#     Found existing installation: idna 3.10━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#     Uninstalling idna-3.10:90m╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#       Successfully uninstalled idna-3.10━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [roboflow]6/7 [roboflow]-headless]
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 requests-toolbelt-1.0.0 roboflow-1.1.63
# Requirement already satisfied: ultralytics in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (8.3.131)
# Requirement already satisfied: numpy>=1.23.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: setuptools in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (80.4.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wkapusniak/projektyPython/Tennis-Analysis/venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YT0Ceq1n3fxAUV8EP78i")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:02<00:00, 19117.97it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 10398.09it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train","tennis-ball-detection-6/tennis-ball-detection-6/train")
shutil.move("tennis-ball-detection-6/test","tennis-ball-detection-6/tennis-ball-detection-6/test")
shutil.move("tennis-ball-detection-6/valid","tennis-ball-detection-6/tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=10 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.3.132 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.131 🚀 Python-3.12.3 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/wkapusniak/projektyPython/Tennis-Analysis/training/tennis-ball-detection-6/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5l6u.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   3540480  ultralytics.nn.modules.conv.Conv             [512, 768, 3, 2]
#   8                  -1  3   5611008  ultralytics.nn.modules.block.C3              [768, 768, 3]
#   9                  -1  1   7079936  ultralytics.nn.modules.conv.Conv             [768, 1024, 3, 2]
#  10                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#  11                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  12                  -1  1    787968  ultralytics.nn.modules.conv.Conv             [1024, 768, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   6200832  ultralytics.nn.modules.block.C3              [1536, 768, 3, False]
#  16                  -1  1    394240  ultralytics.nn.modules.conv.Conv             [768, 512, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  20                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  24                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  27                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  3   5807616  ultralytics.nn.modules.block.C3              [1024, 768, 3, False]
#  30                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  3  10496000  ultralytics.nn.modules.block.C3              [1536, 1024, 3, False]
#  33    [23, 26, 29, 32]  1   9902356  ultralytics.nn.modules.head.Detect           [1, [256, 512, 768, 1024]]
# YOLOv5l6u summary: 314 layers, 86,018,708 parameters, 86,018,692 gradients, 137.7 GFLOPs
#
# Transferred 891/899 items from pretrained weights
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1135.0±869.8 MB/s, size: 91.9 KB)
# train: Scanning /home/wkapusniak/projektyPython/Tennis-Analysis/training/tennis-
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 19.6±29.6 MB/s, size: 83.0 KB)
# val: Scanning /home/wkapusniak/projektyPython/Tennis-Analysis/training/tennis-ba
# Plotting labels to /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 147 weight(decay=0.0), 156 weight(decay=0.0005), 155 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 6 dataloader workers
# Logging results to /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      10.4G      3.396      91.94       1.02         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      10.2G      4.022      16.14      1.082         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      10.2G      3.455       3.12     0.9595         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      10.2G      3.615      2.462      1.028         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      10.2G      3.319      2.404     0.9976         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      10.5G      3.319      2.423     0.9672         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      10.5G      3.021      2.198      0.946         11        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101      0.343      0.129     0.0837      0.021
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      10.5G      2.974      1.887     0.9219         11        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101      0.612      0.307      0.281     0.0651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      10.2G      3.026      2.043     0.9213         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101      0.363      0.208      0.163     0.0345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      10.5G      2.864       1.77     0.9213         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101      0.449      0.297      0.254     0.0728
#
# 10 epochs completed in 0.976 hours.
# Optimizer stripped from /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train/weights/last.pt, 172.6MB
# Optimizer stripped from /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train/weights/best.pt, 172.6MB
#
# Validating /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.131 🚀 Python-3.12.3 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# YOLOv5l6u summary (fused): 167 layers, 85,972,308 parameters, 0 gradients, 137.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100        101       0.45      0.297      0.254     0.0726
# Speed: 5.9ms preprocess, 33.5ms inference, 0.1ms loss, 7.0ms postprocess per image
# Results saved to /home/wkapusniak/projektyPython/Tennis-Analysis/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
